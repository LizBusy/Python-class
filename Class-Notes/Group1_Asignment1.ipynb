# %% [markdown]
# Lambda Functions

# %% [markdown]
# Standard way

# %%
def square(x):
    return x ** 2

# %% [markdown]
# Lambda way

# %%
# keyword parameter : expression
lambda x : x ** 2
square(6)
# Out:
# 36

# %% [markdown]
# Exaple 1: Basic math

# %%
# A function that adds 10 to any number
add_ten = lambda x : x + 10

print(add_ten(5))
# Out:
# 15

# %% [markdown]
# Example 2: Multiple Arguments

# %%
# Function  to calculate the area of a rectangle

# %% [markdown]
# APIs

# %% [markdown]
# APIs
# Application programming interface - a way for different software systems to communicate with each other.
#
# Example:
# Uber uses Google maps + API sents location data
#
# The "contract" idea
# An API works like a contract between two systems:
# Provider(server): Promises to give daa if requested correctly.
# Consumer (Client): Must request data in the correct format
# If the client sends the wrong request (e.g., invalid city name), the server rejects it.
# If the request is correct, the server responds with data—without revealing how it works internally.
#
# How APIs Work
# 1. Request (Client → Server)
# The client asks for data using:
# URL (Endpoint): Where to go (e.g. /users)
# Method:
# GET → retrieve data
# POST → send data
# Headers: Extra info (like authentication)
# Body: Data being sent (mainly for POST/PUT)
#
# 2. Processing (Server side)
# The server:
#
# Checks if request is valid
# Fetches data from database
# Formats the result
#
# 3. Response (Server → Client)
#
# The server sends back:
#
# Status Code: Shows success or error (e.g., 200 = OK, 404 = Not found)
# Headers: Extra info (like rate limits)
# Body: The actual data (often in JSON format)
#
# Think of an API like ordering food:
#
# You = Client
# Restaurant = Server
# Menu rules = API contract
# Order = Request
# Food delivered = Response
#
# You don’t need to know how the kitchen works—just how to order correctly.

# %%
# JSON Format
json_string = """ 
{"name" : "Alice", "age" : "22", "course" : "engineering" }
"""

print(json_string)
print(type(json_string))
# Out:
#
# {"name" : "Alice", "age" : "22", "course" : "engineering" }
#
# <class 'str'>

# %%
# This is a python dictionary
student = {"name" : "Alice", "age" : "22", "course" : "engineering"}

print(student)
# Out:
# {'name': 'Alice', 'age': '22', 'course': 'engineering'}

# %%
# JSON 
""" student = {"name" : "Alice", "age" : "22", "course" : "engineering"}"""

print(student)
# Out:
# {'name': 'Alice', 'age': '22', 'course': 'engineering'}

# %% [markdown]
# The Data Format: JSON
#
# While APIs can return XML or HTML, 95%
#  of modern APIs return JSON (JavaScript Object Notation).
#
# Why JSON? It is lightweight and text-based.
# The Python Connection: JSON maps perfectly to Python data structures.
#
# JSON Object {}  →  → Python Dictionary dict
#
# JSON Array []   →  → Python List list
#
# JSON null       →  → Python None
#
# JSON true       →  → Python True

# %% [markdown]
# HTTP Status Codes: The Server's Language
# You must memorize the categories to debug effectively.
#
# 200 OK: The standard success response.
#
# 201 Created: Success, specifically for a POST request (a
# new record was made).
#
# 204 No Content: Success, but there is nothing to return (common for DELETE).
#
# 400 Bad Request: You sent invalid JSON or missing parameters.
#
#
# 401 Unauthorized: You are missing an API Key or Password.
#
# 403 Forbidden: You have a key, but you don't have permission for this specific file.
#
# 404 Not Found: The Endpoint (URL) is wrong or the ID doesn't exist.
#
# 429 Too Many Requests: You are spamming the server (Rate Limiting).
#
# 500 Internal Server Error: The server crashed. This is not your fault.

# %% [markdown]
# Tasks
# 1. Use weathermap.api to get weather for Kirinyaga/ for the city you'd love to visit in the world
# Get the Weather For the city you would love to visit in the world using the [Weather API](https://openweathermap.org/api)
#
# 2. Get the top 5 albums by litseners of your favourite artist on sportify using [Sportify API](https://developer.spotify.com/documentation/web-api)

# %%
# Use weathermap.api to get weather for Kirinyaga/ for the city you'd love to visit in the world

import requests
import datetime
city = "Tokyo"
api_key = "c59b58dd9f606894b6f171078a42460e"

url = f"https://api.openweathermap.org/data/2.5/weather?q={"Tokyo"}&appid={"c59b58dd9f606894b6f171078a42460e"}"

response = requests.get(url).json()

print(response)
# Out:
# {'coord': {'lon': 139.6917, 'lat': 35.6895}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 289.21, 'feels_like': 288.31, 'temp_min': 288.49, 'temp_max': 289.73, 'pressure': 1022, 'humidity': 55, 'sea_level': 1022, 'grnd_level': 1020}, 'visibility': 10000, 'wind': {'speed': 2.06, 'deg': 30}, 'clouds': {'all': 75}, 'dt': 1777528660, 'sys': {'type': 2, 'id': 268395, 'country': 'JP', 'sunrise': 1777492252, 'sunset': 1777541157}, 'timezone': 32400, 'id': 1850144, 'name': 'Tokyo', 'cod': 200}

# %%
# Get the top 5 albums by litseners of your favourite artist on sportify using [Sportify API](https://developer.spotify.com/documentation/web-api)

import requests

client_ID = "7c4da57c37514b19b29bfb5ee48cd884"
client_secret = "b4747a65648d453091f821510bf61b6c"
end_point = "https://api.spotify.com/v1/me"

auth = f"{7c4da57c37514b19b29bfb5ee48cd884} : {b4747a65648d453091f821510bf61b6c}"
a
