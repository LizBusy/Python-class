# %% [markdown]
# ### 1. Create a Database and Tables Create an SQLite database named company.db.
#
# Create two tables: employees and departments
#
# Define a foreign key relationship where each employee belongs to a department.
#
# 2. Insert Sample Data
# Add atleast 3 departments.
#
# Add at least 5 employees and assign them to different departments.
#
# 3. Perform CRUD Operations
#
# Read: Retrieve all employees along with their corresponding department names.
#
# Update: Change a specific employee’s department.
#
# Delete: Remove an employee from the database.

# %%
import sqlite3

connectingtodatabase = sqlite3.connect("company.db")

# %% [markdown]
# NoSQL
#
# Not Only SQL
#
# It's a type of database designed for:
# - Flexible data.
# - Fast scaling.
# - Huge amounts of information.
# - Modern websites/apps.
#
# Unlike SQL databases, NoSQL databases do not always use tables and rows.

# %% [markdown]
# SQL VS NoSQL

# %% [markdown]
# SQL - NoSQL
#  DIFFERENCES
#
# - Tables                               - Flexible structures
#
# - Rows and columns                     - Documents or key-values or graphs
#
# - Fixed schema                         - Dynamic schema
#
# - Structured data                      - Unstructured data
#
# - SQLite, MySQL                        - MongoDB, Firebase
#
# - Best for banking                     - Best for apps or social media
#
# - Scalabilty(vertical-big server)      - (Horizontal- more servers)

# %% [markdown]
# REAL-WORLD EXAMPLES
#
# SQL
#
# - Best for: hospitals, banks, school systems, payroll.
#
# - This is because relationships matter.
#
#
# NoSQL
#
# - Best for: chat apps, social media, analytics, AI apps, recommendation systems.
#
# - This is because data changes constantly.

# %% [markdown]
# MAIN TYPES OF NoSQL
#
# 1. Document Databases
#
# - Stores data like JSON documents.
# - This is powerful because different users can have different fields.
# - Also no need for identical columns.
# - Example: MongoDB
#
# Instead of tables, example:

# %%
# JSON
{
    "name": "Tatiana",
    "age": 21,
    "mood_score": 7,
    "interests": ["Lifestyle", "Mental Health"]
}
# Out:
# {'name': 'Tatiana',
#  'age': 21,
#  'mood_score': 7,
#  'interests': ['Lifestyle', 'Mental Health']}

# %% [markdown]
# 2. Key-Value Databases
#
# - It's very fast.
# - Used for: caching, sessions, settings.
# - Example: Redis

# %% [markdown]
# 3. Graph Databases
#
# - Stores relations.
# - Used for: social networks, recommendations.
# - Example: Neo4j

# %% [markdown]
# 4. Column Databases
#
# - Stores data by columns instead of rows.
# - Used for: analytics, huge datasets.
# - Example: Cassandra

# %% [markdown]
# MongoDB

# %%
# %pip install pymongo python-dotenv
# Out:
# Collecting pymongo
#   Downloading pymongo-4.17.0-cp313-cp313-win_amd64.whl.metadata (10 kB)
# Collecting python-dotenv
#   Downloading python_dotenv-1.2.2-py3-none-any.whl.metadata (27 kB)
# Collecting dnspython<3.0.0,>=2.6.1 (from pymongo)
#   Downloading dnspython-2.8.0-py3-none-any.whl.metadata (5.7 kB)
# Downloading pymongo-4.17.0-cp313-cp313-win_amd64.whl (972 kB)
#    ---------------------------------------- 0.0/972.8 kB ? eta -:--:--
#    ---------------------------------------- 0.0/972.8 kB ? eta -:--:--
#    ---------- ----------------------------- 262.1/972.8 kB ? eta -:--:--
#    ---------- ----------------------------- 262.1/972.8 kB ? eta -:--:--
#    -------------------- ----------------- 524.3/972.8 kB 807.3 kB/s eta 0:00:01
#    ------------------------------ ------- 786.4/972.8 kB 790.9 kB/s eta 0:00:01
#    ---------------------------------------- 972.8/972.8 kB 825.8 kB/s  0:00:01
# Downloading dnspython-2.8.0-py3-none-any.whl (331 kB)
# Downloading python_dotenv-1.2.2-py3-none-any.whl (22 kB)
# Installing collected packages: python-dotenv, dnspython, pymongo
#
#    ---------------------------------------- 0/3 [python-dotenv]
#    ------------- -------------------------- 1/3 [dnspython]
#    ------------- -------------------------- 1/3 [dnspython]
#    ------------- -------------------------- 1/3 [dnspython]
#    ------------- -------------------------- 1/3 [dnspython]
#    ------------- -------------------------- 1/3 [dnspython]
#    ------------- -------------------------- 1/3 [dnspython]
#    ------------- -------------------------- 1/3 [dnspython]
#    ------------- -------------------------- 1/3 [dnspython]
#    ------------- -------------------------- 1/3 [dnspython]
#    ------------- -------------------------- 1/3 [dnspython]
#    ------------- -------------------------- 1/3 [dnspython]
#    ------------- -------------------------- 1/3 [dnspython]
#    ------------- -------------------------- 1/3 [dnspython]
#    ------------- -------------------------- 1/3 [dnspython]
#    ------------- -------------------------- 1/3 [dnspython]
#    ------------- -------------------------- 1/3 [dnspython]
#    ------------- -------------------------- 1/3 [dnspython]
#    ------------- -------------------------- 1/3 [dnspython]
#    ------------- -------------------------- 1/3 [dnspython]
#    ------------- -------------------------- 1/3 [dnspython]
#    ------------- -------------------------- 1/3 [dnspython]
#    ------------- -------------------------- 1/3 [dnspython]
#    ------------- -------------------------- 1/3 [dnspython]
#    ------------- -------------------------- 1/3 [dnspython]
#    ------------- -------------------------- 1/3 [dnspython]
#    ------------- -------------------------- 1/3 [dnspython]
#    ------------- -------------------------- 1/3 [dnspython]
#    ------------- -------------------------- 1/3 [dnspython]
#    ------------- -------------------------- 1/3 [dnspython]
#    -------------------------- ------------- 2/3 [pymongo]
#    -------------------------- ------------- 2/3 [pymongo]
#    -------------------------- ------------- 2/3 [pymongo]
#    -------------------------- ------------- 2/3 [pymongo]
#    -------------------------- ------------- 2/3 [pymongo]
#    -------------------------- ------------- 2/3 [pymongo]
#    -------------------------- ------------- 2/3 [pymongo]
#    -------------------------- ------------- 2/3 [pymongo]
#    -------------------------- ------------- 2/3 [pymongo]
#    -------------------------- ------------- 2/3 [pymongo]
#    -------------------------- ------------- 2/3 [pymongo]
#    -------------------------- ------------- 2/3 [pymongo]
#    -------------------------- ------------- 2/3 [pymongo]
#    -------------------------- ------------- 2/3 [pymongo]
#    -------------------------- ------------- 2/3 [pymongo]
#    -------------------------- ------------- 2/3 [pymongo]
#    -------------------------- ------------- 2/3 [pymongo]
#    -------------------------- ------------- 2/3 [pymongo]
#    -------------------------- ------------- 2/3 [pymongo]
#    -------------------------- ------------- 2/3 [pymongo]
#    -------------------------- ------------- 2/3 [pymongo]
#    -------------------------- ------------- 2/3 [pymongo]
#    -------------------------- ------------- 2/3 [pymongo]
#    -------------------------- ------------- 2/3 [pymongo]
#    -------------------------- ------------- 2/3 [pymongo]
#    -------------------------- ------------- 2/3 [pymongo]
#    -------------------------- ------------- 2/3 [pymongo]
#    -------------------------- ------------- 2/3 [pymongo]
#    -------------------------- ------------- 2/3 [pymongo]
#    -------------------------- ------------- 2/3 [pymongo]
#    ---------------------------------------- 3/3 [pymongo]
#
# Successfully installed dnspython-2.8.0 pymongo-4.17.0 python-dotenv-1.2.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.0.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
from dotenv import load_dotenv
from pymongo import MongoClient

# Secret Password
load_dotenv()
uri = os.getenv("MONGO_URI")

client = MongoClient(uri)

db = client["school"]

students = db["students"]
try:
    client.admin.command('ping')
    print("Successfully connected to MONGODB!")
except Exception as e:
    print(e)
# Out:
# Successfully connected to MONGODB!

# %%
# Insert one

student_001 = {
    "name": "Takopi San",
    "age": 16,
    "gpa": 3.8,
    "courses": ["Math", "Physics"],   # Lists are allowed
    "address": {"city": "Osaka"}      # Nested Dictionaries are allowed
    }

result = students.insert_one(student_001)
print(f"Created Student ID: {result.inserted_id}")
# Out:
# Created Student ID: 69fda90f8aca64d240d7138d

# %%
# Insert many

batch_data = [
    {"name": "Megumi", "age": 18, "gpa": 4.0},
    {"name": "Sukuna", "age": 17, "gpa": 2.5},
    {"name": "Jogo", "age": 17, "gpa": 2.4},
    {"name": "Mahito", "age": 19, "gpa": 1.9}
]

result = students.insert_many(batch_data)
print(f"Created {len(result.inserted_ids)} students.")
# Out:
# Created 4 students.

# %%
# Read (Query Operations)

# .find()

# Find Sukuna

sukuna = students.find_one({"name": "Sukuna"})
print(sukuna)
# Out:
# {'_id': ObjectId('69fdad528aca64d240d7138f'), 'name': 'Sukuna', 'age': 17, 'gpa': 2.5}

# %% [markdown]
# - Common Query Operators
#     - $eq : Equal to
#     - $gt : Greater than
#     - $lt : Less than
#     - $gte : Greater than or Equal to
#     - $lte : Less than or Equal to
#     - $in : Match any value in a list ({"age": {"$in": [14, 15]}})
#     - $set : Only change certain field

# %%
# Find Many (Get List)
# Find all students with GPA > 3.0
# Syntax: {field: {$operator: value}}
high_achievers = students.find({"gpa": {"$gt": 3.0}})

print("High Achievers:")
for student in high_achievers:
    print(f"- {student['name']} (GPA: {student['gpa']})")
# Out:
# High Achievers:
# - Takopi San (GPA: 3.8)
# - Takopi San (GPA: 3.8)
# - Takopi San (GPA: 3.8)
# - Megumi (GPA: 4.0)

# %%
# Update

# Simple Update ($set)

# Change Takopi's age to 17

students.update_one(
    {"name": "Takopi San"},   #Filter (who?)
    {"$set": {"age": 17}}      # Action(What?)       
)
# Out:
# UpdateResult({'n': 1, 'electionId': ObjectId('7fffffff00000000000000d1'), 'opTime': {'ts': Timestamp(1778234533, 5), 't': 209}, 'nModified': 1, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1778234533, 5), 'signature': {'hash': b'n\xf3\x08\xc9\xf4\xc3\xa0{\xb8\xe3\xc4!\xde\x91Q\t]\x9d\x03\x87', 'keyId': 7574143984335847430}}, 'operationTime': Timestamp(1778234533, 5), 'updatedExisting': True}, acknowledged=True)

# %%
# List Modification ($push)

students.update_one(
    {"name": "Takopi San"},
    {"$push": {"courses": "Chemistry"}}    # $push appends
)
# Out:
# UpdateResult({'n': 1, 'electionId': ObjectId('7fffffff00000000000000d1'), 'opTime': {'ts': Timestamp(1778235027, 49), 't': 209}, 'nModified': 1, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1778235027, 50), 'signature': {'hash': b'\xf0\x17oQL\xc0.\xc6\xce\xd4I\xf3m7\xb4\xaa`\x8cpI', 'keyId': 7574143984335847430}}, 'operationTime': Timestamp(1778235027, 49), 'updatedExisting': True}, acknowledged=True)

# %%
# Increment ($inc)

# It's Takopi's birthday! Add 1 to his age.

students.update_one(
    {"name": "Takopi San"},
    {"$inc": {"age": 1}}    # $inc : selects and updates values
)
# Out:
# UpdateResult({'n': 1, 'electionId': ObjectId('7fffffff00000000000000d1'), 'opTime': {'ts': Timestamp(1778235546, 47), 't': 209}, 'nModified': 1, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1778235546, 48), 'signature': {'hash': b'!\x9a0\x88R\xd8\xa1\xfe*2\xa7\xe2\xd5\xb1\x869\xaa\xaeC\x8b', 'keyId': 7574143984335847430}}, 'operationTime': Timestamp(1778235546, 47), 'updatedExisting': True}, acknowledged=True)

# %%
# Delete

#Delete one
students.delete_one({"name": "Jogo"})
# Out:
# DeleteResult({'n': 1, 'electionId': ObjectId('7fffffff00000000000000d1'), 'opTime': {'ts': Timestamp(1778235791, 18), 't': 209}, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1778235791, 18), 'signature': {'hash': b'&\x82b\xb3\x00=\xbe\xef\t\xf0|\xa7l\xd1\xcfXX:\xf4\xa9', 'keyId': 7574143984335847430}}, 'operationTime': Timestamp(1778235791, 18)}, acknowledged=True)

# %%
# Delete many

# Delete everyone with a low gpa
# Everyoe with a gpa < 2.0
result = students.delete_many({"gpa": {"$lt": 2.0}})
print(f"Expelled {result.deleted_count} student.")
# Out:
# Expelled 1 student.
