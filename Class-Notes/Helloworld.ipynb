# %% [markdown]
# # Introduction to Python

# %%
ArtemisII_Astronauts = {"Reid":39, 
                         "Chari":42, 
                         "Kim":25}

# %%
# Use the 'or' keyword to check if Chari is a key in the 'ArtemisII_Astronauts' Dictionary
# and if the minimum age of all astronauts is < 20

if "Chari" in ArtemisII_Astronauts.keys() or min(ArtemisII_Astronauts()) < 20:
    print(True)
else:
 print(False)
# Out:
# True

# %%
print("Class-Notes")
# Out:
# Class-Notes

# %%
#Customer Feedback Scores
